# %%
#  Write a Python program to append text to a file and display the text.

with open(r"C:\Users\ASUS\OneDrive\Desktop\append.txt", "a") as file:
    file.write("\n This in newly appended line")
with open(r"C:\Users\ASUS\OneDrive\Desktop\append.txt", "r") as file:
    content = file.read()
    print("Updated file content: \n")
    print(content)
# Out:
# Updated file content:
#
# Updated file content:
#
# Hello World!
# This is the newly appended line.
#  This in newly appended line
