# %%
# Write a Python program to combine values in python list of dictionaries. 

from collections import Counter

data = [
    {"item" : "item 1", "amount" : 400},
    {"item" : "item 2", "amount" : 300},
    {"item" : "item 3", "amount" : 750}
]

result = Counter()

for entry in data:
    result[entry["item"]] += entry["amount"]

print("Combine result: ", result)
# Out:
# Combine result:  Counter({'item 3': 750, 'item 1': 400, 'item 2': 300})
