# %%
# Write a Python script to concatenate following dictionaries to create 
# a new one.

dict1 = {1: "apple", 2: "banana"}
dict2 = {3: "cherry", 4: "date"}
dict3 = {5: "fig", 6: "grape"}

new_dict = {}
new_dict.update(dict1)
new_dict.update(dict2)
new_dict.update(dict3)

print("concatenated dictionary (using update): ", new_dict)

new_dict_unpack = {**dict1, **dict2, **dict3}
print("Concatenated dictionary (using unpacking): ", new_dict_unpack)
# Out:
# concatenated dictionary (using update):  {1: 'apple', 2: 'banana', 3: 'cherry', 4: 'date', 5: 'fig', 6: 'grape'}
# Concatenated dictionary (using unpacking):  {1: 'apple', 2: 'banana', 3: 'cherry', 4: 'date', 5: 'fig', 6: 'grape'}
