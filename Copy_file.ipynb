# %%
# Write a Python program to copy the contents of a file to another file.

try:
    with open(r"C:\Users\ASUS\OneDrive\Desktop\source.txt", "r") as src:
        content = src.read()
    
    with open(r"C:\Users\ASUS\OneDrive\Desktop\destination.txt", "w") as dest:
        dest.write(content)
    
    print("Contents copied from 'source.txt' to 'destination.txt' ")
except FileNotFoundError:
    print("Error: The source file was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Contents copied from 'source.txt' to 'destination.txt'
