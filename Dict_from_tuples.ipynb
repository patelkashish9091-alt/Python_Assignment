# %%
# How will you create a dictionary using tuples in python? 

tuple = [(1, "apple"), (2, "banana"), (3, "cherry")]

my_dict = dict(tuple)

print("Dictionary is: ", my_dict)
# Out:
# Dictionary is:  {1: 'apple', 2: 'banana', 3: 'cherry'}
