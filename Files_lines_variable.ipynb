# %%
#  Write a Python program to read a file line by line store it into a variable.

try:
    with open(r"C:\Users\ASUS\OneDrive\Desktop\example.txt", "r") as file:
        lines_variable = [line.strip() for line in file]
        
        print("File content stored in variable:\n")
        print(lines_variable)
except FileNotFoundError:
    print("Error: The file 'example.txt' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File content stored in variable:
#
# ["['Hello World!', 'Python is fun', 'File handling example']"]
