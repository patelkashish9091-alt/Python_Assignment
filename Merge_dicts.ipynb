# %%
#  Write a Python script to merge two Python dictionaries.

dict1 = {"apple" : 10, "banana" : 5}
dict2 = {"cherry" : 20, "date" : 15}

merged_dict = dict1.copy()
merged_dict.update(dict2)

print("Merged dictionary (using update): ", merged_dict)

merged_dict_unpack = {**dict1, **dict2}
print("Merged dictionary (using unpaacking): ", merged_dict_unpack)
# Out:
# Merged dictionary (using update):  {'apple': 10, 'banana': 5, 'cherry': 20, 'date': 15}
# Merged dictionary (using unpaacking):  {'apple': 10, 'banana': 5, 'cherry': 20, 'date': 15}
