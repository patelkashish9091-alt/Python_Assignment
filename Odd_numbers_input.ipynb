# %%
#  Write python program that user to enter only odd numbers, else 
# will raise an exception.

try:
    num = int(input("Enter the number: "))
    if num % 2 == 0:
        raise ValueError("Only odd numbers are allowed! ")
    else:
        print(f"Great! You entered an odd number: {num}")
except ValueError as e:
    print(f"Error: {e}")
# Out:
# Great! You entered an odd number: 55
