# %%
# Write a Python program to split a list into different variables. 

sample_list = [10, 20, 30, 40]

a, b, c, d = sample_list

print("a = ", a)
print("b = ", b)
print("c = ", c)
print("d = ", d)
# Out:
# a =  10
# b =  20
# c =  30
# d =  40
