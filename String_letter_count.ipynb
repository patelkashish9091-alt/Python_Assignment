# %%
# Sample string: 'w3resource'

from collections import Counter

my_string = "w3resource"

letter_count = Counter(my_string)

print("Original String: ", my_string)
print("Dictionary of letter counts: ", dict(letter_count))
# Out:
# Original String:  w3resource
# Dictionary of letter counts:  {'w': 1, '3': 1, 'r': 2, 'e': 2, 's': 1, 'o': 1, 'u': 1, 'c': 1}
