# %%
# Write a python program to sum of the first n positive number.

total = 0
for i in range(1,11):
    total = total + i
print("Sum of first n postive number is: ", total)
# Out:
# Sum of first n postive number is:  55
