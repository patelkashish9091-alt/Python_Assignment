# %%
# Write a Python program to find the highest 3 values in a dictionary 

my_dict = {"apple" : 10, "banana" : 5, "cherry" : 20, "date" : 15, "fig" : 25}

top3 = sorted(my_dict.items(), key=lambda item: item[1], reverse=True)[:3]

print("Original dictionary: ", my_dict)
print("Top 3 highest values: ", top3)
# Out:
# Original dictionary:  {'apple': 10, 'banana': 5, 'cherry': 20, 'date': 15, 'fig': 25}
# Top 3 highest values:  [('fig', 25), ('cherry', 20), ('date', 15)]
