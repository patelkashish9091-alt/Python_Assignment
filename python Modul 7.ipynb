# %% [markdown]
# # Questions of python
# # Module 7.
#
# 1) What are the types of applications?
# = Applications are generally categorized based on their architecture and platform:
# Web Applications
# Desktop Applications
# Mobile Applications
# Enterprise Applications.
#
# 2) What is programming ?
# = Programming is the process of creating a set of instructions that tells a computer how to perform task
#
# 3) What is python ?
# = python is a high level,interpreted and object-oriented ,simple ,easy to learn programming languages.
#
# 4) How memory is managed in python ?
# = its handled automactically through the following components:
# Private haep
# Gaqrbage collecter
# Reference counting.
#
# 5) What is purpose continuing statement in python?
# = The continue statement is used inside loops to skip the remaining code inside the current iteration..
#
# 6) What are negative indexes and why are they used?
# = they allows you to access elements of a sequences starting from the end instead of the beginning index -1 refers to last elements ,-2 refers to the second to last.
#
# 7) What is list?How will you reverse a list?
# = its a inbuilt ordered,mutuable collections data type that allows store multiples items.
#
# 8) suppose list1 is [2,33,222,14,25]  what is list[-1]?
# = ans is 25
#
# 9) Difference between append() and extend() methods?
# = append() means single elements to the end of a list
# = extend() means each item indivally..
#
# 10) How will you compare two lists ?
# = using several approaches depends on what you need to check:
# equality(==)
# order - independent comparison
# identity(is).
#
# 11) What is tuple?
# = its a in built ,ordered collection data types in python that allows you to store multiple items in a single variables().
#
# 12) How will you create a dictionary using tuples in python?
# = from a sequence of key-value tuples by passing it into the built- in dict() constructor.
#
# 13) How do you check the preence of a key in a dictonary?
# = by using in keyword.
#
# 14) How many Basic types of functions are available in python?
# = Two basics types of functions:
# Built in functions
# user defined.
#
# 15) How can you pick a random item from a list or tuple?
# = random.choice().
#
# 16) How can you pick a random item from a range?
# = you can combine a python range() with random.choice(), random.randrange()
#
# 17) How can you get a random no in python?
# = Floating point no = 0.0 to 1.0
# = integer no = random.rfandint
#
# 18) How will you set the starting value in generating random no?
# = using random.seed() function.
#
# 19) What is the file functions in python?
# = The open() function is used to create,open,read,write,appends files in python.
#
# 20) Explain Exception handing ? What is an error in python?
# = An error is an problem in a program that stops execution.
# = Execution handling is used to handle runtime errors using try and except..
#
# 21) How many except statements can a try except block have?
# = A try block can have multiple except.
# Built - in - functions
# - ValueError
# - ZeroDivisionError
# -KeyError
# NameError
#
# 22) When will the else part of try-except-else be executed?
# = The else block is executed when no exception occurs in the try block..
